# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import seaborn as sns

# %%
df = pd.read_csv("top100_kdrama.csv", index_col = 0)
df = df.reset_index()
df
# Out:
#                              Name  Year of release  \
# 0                  Move to Heaven             2021
# 1               Hospital Playlist             2020
# 2                  Flower of Evil             2020
# 3             Hospital Playlist 2             2021
# 4                       My Mister             2018
# ..                            ...              ...
# 95                       Vagabond             2019
# 96                    Doctor John             2019
# 97       When the Camellia Blooms             2019
# 98  Because This Is My First Life             2017
# 99               Fight For My Way             2017
#
#                      Aired Date              Aired On  Number of Episode  \
# 0                  May 14, 2021                Friday                 10
# 1   Mar 12, 2020 - May 28, 2020              Thursday                 12
# 2   Jul 29, 2020 - Sep 23, 2020   Wednesday, Thursday                 16
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of                              Name  Year of release  \
# 0                  Move to Heaven             2021
# 1               Hospital Playlist             2020
# 2                  Flower of Evil             2020
# 3             Hospital Playlist 2             2021
# 4                       My Mister             2018
# ..                            ...              ...
# 95                       Vagabond             2019
# 96                    Doctor John             2019
# 97       When the Camellia Blooms             2019
# 98  Because This Is My First Life             2017
# 99               Fight For My Way             2017
#
#                      Aired Date              Aired On  Number of Episode  \
# 0                  May 14, 2021                Friday                 10
# 1   Mar 12, 2020 - May 28, 2020              Thursday                 12
# 2   Jul 29, 2020 - Sep 23, 2020   Wednesday, Thursday                 16
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                              Name  Year of release  \
# 0                  Move to Heaven             2021
# 1               Hospital Playlist             2020
# 2                  Flower of Evil             2020
# 3             Hospital Playlist 2             2021
# 4                       My Mister             2018
# ..                            ...              ...
# 95                       Vagabond             2019
# 96                    Doctor John             2019
# 97       When the Camellia Blooms             2019
# 98  Because This Is My First Life             2017
# 99               Fight For My Way             2017
#
#                      Aired Date              Aired On  Number of Episode  \
# 0                  May 14, 2021                Friday                 10
# 1   Mar 12, 2020 - May 28, 2020              Thursday                 12
# 2   Jul 29, 2020 - Sep 23, 2020   Wednesday, Thursday                 16
# ...

# %%
d=df['Synopsis'].str.contains('Korea')
df[d].head()
# Out:
#                     Name  Year of release                   Aired Date  \
# 8              Mr. Queen             2020  Dec 12, 2020 - Feb 14, 2021
# 13              Vincenzo             2021  Feb 20, 2021 - May  2, 2021
# 14  Crash Landing on You             2019  Dec 14, 2019 - Feb 16, 2020
# 17          Mr. Sunshine             2018  Jul  7, 2018 - Sep 30, 2018
# 23                  D.P.             2021                 Aug 27, 2021
#
#              Aired On  Number of Episode         Network       Duration  \
# 8    Saturday, Sunday                 20            tvN   1 hr. 20 min.
# 13   Saturday, Sunday                 20  Netflix,  tvN   1 hr. 25 min.
# 14   Sunday, Saturday                 16  Netflix,  tvN   1 hr. 25 min.
# 17   Saturday, Sunday                 24  Netflix,  tvN   1 hr. 20 min.
# 23             Friday                  6        Netflix         50 min.
#
#               Content Rating  \
# 8   15+ - Teens 15 or older
# 13  15+ - Teens 15 or older
# ...

# %%
v=df['Synopsis'].str.contains('U.S')
df[v].head()
# Out:
#             Name  Year of release                   Aired Date  \
# 17  Mr. Sunshine             2018  Jul  7, 2018 - Sep 30, 2018
#
#              Aired On  Number of Episode         Network       Duration  \
# 17   Saturday, Sunday                 24  Netflix,  tvN   1 hr. 20 min.
#
#               Content Rating  \
# 17  15+ - Teens 15 or older
#
#                                              Synopsis  \
# 17  Mr. Sunshine centers on a young boy born into ...
#
#                                                  Cast  \
# 17  Lee Byung Hun, Kim Tae Ri, Kim Min Jung, Yoo Y...
#
#                                            Genre  \
# 17  Military,  Historical,  Romance,  Melodrama
#
#                                                  Tags Rank  Rating
# 17  Independent Female Lead, Strong Male Lead, Str...  #18     8.9

# %%
v2=df['Synopsis'].str.contains('United States')
df[v2].head()
# Out:
#                Name  Year of release                   Aired Date  \
# 17     Mr. Sunshine             2018  Jul  7, 2018 - Sep 30, 2018
# 29  The Penthouse 2             2021  Feb 19, 2021 - Apr  2, 2021
#
#              Aired On  Number of Episode         Network       Duration  \
# 17   Saturday, Sunday                 24  Netflix,  tvN   1 hr. 20 min.
# 29   Friday, Saturday                 13            SBS   1 hr. 15 min.
#
#               Content Rating  \
# 17  15+ - Teens 15 or older
# 29  15+ - Teens 15 or older
#
#                                              Synopsis  \
# 17  Mr. Sunshine centers on a young boy born into ...
# 29  After successfully framing Oh Yoon Hee, Cheon ...
#
#                                                  Cast  \
# 17  Lee Byung Hun, Kim Tae Ri, Kim Min Jung, Yoo Y...
# 29  Kim So Yeon, Eugene, Lee Ji Ah, Uhm Ki Joon, Y...
#
#                                            Genre  \
# 17  Military,  Historical,  Romance,  Melodrama
# ...

# %%
d2=df['Synopsis'].str.contains('Kim')
df[d2].head()
# Out:
#                Name  Year of release                   Aired Date  \
# 5   Prison Playbook             2017  Nov 22, 2017 - Jan 18, 2018
# 6        Reply 1988             2015  Nov  6, 2015 - Jan 16, 2016
# 8         Mr. Queen             2020  Dec 12, 2020 - Feb 14, 2021
# 18           Healer             2014  Dec  8, 2014 - Feb 10, 2015
# 20           Goblin             2016  Dec  2, 2016 - Jan 21, 2017
#
#                 Aired On  Number of Episode         Network       Duration  \
# 5    Wednesday, Thursday                 16  Netflix,  tvN   1 hr. 32 min.
# 6       Friday, Saturday                 20            tvN   1 hr. 40 min.
# 8       Saturday, Sunday                 20            tvN   1 hr. 20 min.
# 18       Monday, Tuesday                 20           KBS2         60 min.
# 20      Friday, Saturday                 16            tvN   1 hr. 22 min.
#
#               Content Rating  \
# 5   15+ - Teens 15 or older
# 6   15+ - Teens 15 or older
# ...

# %%
new=pd.concat([df[d],df[d2],df[v],df[v2]])

# %%
new
# Out:
#                                Name  Year of release  \
# 8                         Mr. Queen             2020
# 13                         Vincenzo             2021
# 14             Crash Landing on You             2019
# 17                     Mr. Sunshine             2018
# 23                             D.P.             2021
# 27                  The Devil Judge             2021
# 37                       Sweet Home             2020
# 39               Chicago Typewriter             2017
# 52                      Moon Lovers             2016
# 62                  The Bridal Mask             2012
# 64              Jewel in the Palace             2003
# 70            My Love from the Star             2013
# 78                       Squid Game             2021
# 5                   Prison Playbook             2017
# 6                        Reply 1988             2015
# 8                         Mr. Queen             2020
# 18                           Healer             2014
# ...

# %%
from collections import Counter
new['Aired On'] = new['Aired On'].str.strip()
week = list()
for days in new['Aired On'].to_list():
    days = days.split(", ")
    for day in days:
        week.append(day)
week = pd.DataFrame.from_dict(Counter(Aired_On_list), orient = 'index').rename(columns = {0:'Count'})
week.sort_values('Count', ascending = False, inplace = True)
week.head(10)
# Out:
#            Count
# Saturday      14
# Friday         9
# Sunday         8
# Monday         5
# Tuesday        5
# Wednesday      5
# Thursday       5

# %%
week = week.reset_index()

# %%
week
# Out:
#        index  Count
# 0   Saturday     14
# 1     Friday      9
# 2     Sunday      8
# 3     Monday      5
# 4    Tuesday      5
# 5  Wednesday      5
# 6   Thursday      5

# %%
plt.figure(figsize=(10, 6))
plt.bar(week['index'], week['Count'], color='skyblue')
plt.xlabel('Day of the Week')
plt.ylabel('Count')
plt.title('Count by Day of the Week')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()
