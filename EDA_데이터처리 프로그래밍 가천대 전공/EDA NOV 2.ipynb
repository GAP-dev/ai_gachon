# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import seaborn as sns

# %%
df = pd.read_csv("top100_kdrama.csv", index_col = 0)
df = df.reset_index()
df
# Out:
#                              Name  Year of release  \
# 0                  Move to Heaven             2021
# 1               Hospital Playlist             2020
# 2                  Flower of Evil             2020
# 3             Hospital Playlist 2             2021
# 4                       My Mister             2018
# ..                            ...              ...
# 95                       Vagabond             2019
# 96                    Doctor John             2019
# 97       When the Camellia Blooms             2019
# 98  Because This Is My First Life             2017
# 99               Fight For My Way             2017
#
#                      Aired Date              Aired On  Number of Episode  \
# 0                  May 14, 2021                Friday                 10
# 1   Mar 12, 2020 - May 28, 2020              Thursday                 12
# 2   Jul 29, 2020 - Sep 23, 2020   Wednesday, Thursday                 16
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of                              Name  Year of release  \
# 0                  Move to Heaven             2021
# 1               Hospital Playlist             2020
# 2                  Flower of Evil             2020
# 3             Hospital Playlist 2             2021
# 4                       My Mister             2018
# ..                            ...              ...
# 95                       Vagabond             2019
# 96                    Doctor John             2019
# 97       When the Camellia Blooms             2019
# 98  Because This Is My First Life             2017
# 99               Fight For My Way             2017
#
#                      Aired Date              Aired On  Number of Episode  \
# 0                  May 14, 2021                Friday                 10
# 1   Mar 12, 2020 - May 28, 2020              Thursday                 12
# 2   Jul 29, 2020 - Sep 23, 2020   Wednesday, Thursday                 16
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                              Name  Year of release  \
# 0                  Move to Heaven             2021
# 1               Hospital Playlist             2020
# 2                  Flower of Evil             2020
# 3             Hospital Playlist 2             2021
# 4                       My Mister             2018
# ..                            ...              ...
# 95                       Vagabond             2019
# 96                    Doctor John             2019
# 97       When the Camellia Blooms             2019
# 98  Because This Is My First Life             2017
# 99               Fight For My Way             2017
#
#                      Aired Date              Aired On  Number of Episode  \
# 0                  May 14, 2021                Friday                 10
# 1   Mar 12, 2020 - May 28, 2020              Thursday                 12
# 2   Jul 29, 2020 - Sep 23, 2020   Wednesday, Thursday                 16
# ...

# %%
d=df.sort_values('Number of Episode',ascending=False)

# %%
d
# Out:
#                          Name  Year of release                   Aired Date  \
# 81                 Once Again             2020  Mar 28, 2020 - Sep 13, 2020
# 64        Jewel in the Palace             2003  Sep 15, 2003 - Mar 23, 2004
# 65       My Father is Strange             2017  Mar  4, 2017 - Aug 27, 2017
# 71                 Empress Ki             2013  Oct 28, 2013 - Apr 29, 2014
# 32         Six Flying Dragons             2015  Oct  5, 2015 - Mar 22, 2016
# ..                        ...              ...                          ...
# 92  Arthdal Chronicles Part 1             2019  Jun  1, 2019 - Jun 16, 2019
# 23                       D.P.             2021                 Aug 27, 2021
# 45  Arthdal Chronicles Part 2             2019  Jun 22, 2019 - Jul  7, 2019
# 47  Arthdal Chronicles Part 3             2019  Sep  7, 2019 - Sep 22, 2019
# 24                    Kingdom             2019                 Jan 25, 2019
#
# ...

# %%
f=df.sort_values('Rating',ascending=False)

# %%
f = f.loc[:, ['Name', 'Year of release', 'Rating']]

# %%
f.head(10)
# Out:
#                    Name  Year of release  Rating
# 0        Move to Heaven             2021     9.2
# 2        Flower of Evil             2020     9.1
# 3   Hospital Playlist 2             2021     9.1
# 4             My Mister             2018     9.1
# 5       Prison Playbook             2017     9.1
# 1     Hospital Playlist             2020     9.1
# 10               Signal             2016     9.0
# 13             Vincenzo             2021     9.0
# 12            Happiness             2021     9.0
# 11            Navillera             2021     9.0

# %%
t=df.sort_values('Number of Episode',ascending=False)
t=t.loc[:, ['Name', 'Year of release', 'Rating']= f.loc[:, ['Name', 'Year of release', 'Rating']]

# %%
dd=df['Rating']==df['Rating'].max()
df[dd]
# Out:
#              Name  Year of release    Aired Date Aired On  Number of Episode  \
# 0  Move to Heaven             2021  May 14, 2021   Friday                 10
#
#     Network Duration                          Content Rating  \
# 0  Netflix   52 min.  18+ Restricted (violence & profanity)
#
#                                             Synopsis  \
# 0  Geu Roo is a young autistic man. He works for ...
#
#                                                 Cast                   Genre  \
# 0  Lee Je Hoon, Tang Jun Sang, Hong Seung Hee, Ju...  Life,  Drama,  Family
#
#                                                 Tags Rank  Rating
# 0  Autism, Uncle-Nephew Relationship, Death, Sava...   #1     9.2

# %%
dd=df['Rating']==df['Rating'].mean()
df[dd]
# Out:
# Empty DataFrame
# Columns: [Name, Year of release, Aired Date, Aired On, Number of Episode, Network, Duration, Content Rating, Synopsis, Cast, Genre, Tags, Rank, Rating]
# Index: []

# %%
# 넷플릭스 또는 tvN 방영되는 드라마 검색
d=df['Name'].str.contains('Love')
df[d].head()
# Out:
#                       Name  Year of release                   Aired Date  \
# 52             Moon Lovers             2016  Aug 29, 2016 - Nov  1, 2016
# 60  It's Okay, That's Love             2014  Jul 23, 2014 - Sep 11, 2014
# 70   My Love from the Star             2013  Dec 18, 2013 - Feb 27, 2014
# 77     Just Between Lovers             2017  Dec 11, 2017 - Jan 30, 2018
#
#                 Aired On  Number of Episode Network       Duration  \
# 52       Monday, Tuesday                 20    SBS         60 min.
# 60   Wednesday, Thursday                 16    SBS         60 min.
# 70   Wednesday, Thursday                 21    SBS         58 min.
# 77       Monday, Tuesday                 16   jTBC   1 hr. 13 min.
#
#               Content Rating  \
# 52  15+ - Teens 15 or older
# 60  15+ - Teens 15 or older
# 70  15+ - Teens 15 or older
# 77  15+ - Teens 15 or older
#
#                                              Synopsis  \
# ...

# %%
o=df.loc[ df['Network'].str.contains('TvN')==False,['Name']]
o.count
# Out:
# <bound method DataFrame.count of                              Name
# 0                  Move to Heaven
# 1               Hospital Playlist
# 2                  Flower of Evil
# 3             Hospital Playlist 2
# 4                       My Mister
# ..                            ...
# 95                       Vagabond
# 96                    Doctor John
# 97       When the Camellia Blooms
# 98  Because This Is My First Life
# 99               Fight For My Way
#
# [100 rows x 1 columns]>

# %%
b=df.loc[df['Number of Episode']<=10,['Name','Rating','Number of Episode']]
b=df.loc[df['Rating']>=9,['Name','Rating','Number of Episode']]
b.head()
# Out:
#                   Name  Rating  Number of Episode
# 0       Move to Heaven     9.2                 10
# 1    Hospital Playlist     9.1                 12
# 2       Flower of Evil     9.1                 16
# 3  Hospital Playlist 2     9.1                 12
# 4            My Mister     9.1                 16

# %%
dd=df['Number of Episode']==df['Number of Episode'].min()
df[dd]
# Out:
#                          Name  Year of release                   Aired Date  \
# 16                    Kingdom             2020                 Mar 13, 2020
# 23                       D.P.             2021                 Aug 27, 2021
# 24                    Kingdom             2019                 Jan 25, 2019
# 45  Arthdal Chronicles Part 2             2019  Jun 22, 2019 - Jul  7, 2019
# 47  Arthdal Chronicles Part 3             2019  Sep  7, 2019 - Sep 22, 2019
# 92  Arthdal Chronicles Part 1             2019  Jun  1, 2019 - Jun 16, 2019
#
#              Aired On  Number of Episode         Network       Duration  \
# 16             Friday                  6        Netflix         45 min.
# 23             Friday                  6        Netflix         50 min.
# 24             Friday                  6        Netflix         51 min.
# 45   Saturday, Sunday                  6  Netflix,  tvN   1 hr. 21 min.
# 47   Saturday, Sunday                  6  Netflix,  tvN   1 hr. 20 min.
# ...

# %%
df['CastNum']=df['Cast'].str.count(',')+1
df.head()
# Out:
#                   Name  Year of release                   Aired Date  \
# 0       Move to Heaven             2021                 May 14, 2021
# 1    Hospital Playlist             2020  Mar 12, 2020 - May 28, 2020
# 2       Flower of Evil             2020  Jul 29, 2020 - Sep 23, 2020
# 3  Hospital Playlist 2             2021  Jun 17, 2021 - Sep 16, 2021
# 4            My Mister             2018  Mar 21, 2018 - May 17, 2018
#
#                Aired On  Number of Episode         Network       Duration  \
# 0                Friday                 10        Netflix         52 min.
# 1              Thursday                 12  Netflix,  tvN   1 hr. 30 min.
# 2   Wednesday, Thursday                 16            tvN   1 hr. 10 min.
# 3              Thursday                 12  Netflix,  tvN   1 hr. 40 min.
# 4   Wednesday, Thursday                 16            tvN   1 hr. 17 min.
#
#                            Content Rating  \
# 0  18+ Restricted (violence & profanity)
# ...

# %%
d=df['Synopsis'].str.contains('Korea')
df[d].head()
# Out:
#                     Name  Year of release                   Aired Date  \
# 8              Mr. Queen             2020  Dec 12, 2020 - Feb 14, 2021
# 13              Vincenzo             2021  Feb 20, 2021 - May  2, 2021
# 14  Crash Landing on You             2019  Dec 14, 2019 - Feb 16, 2020
# 17          Mr. Sunshine             2018  Jul  7, 2018 - Sep 30, 2018
# 23                  D.P.             2021                 Aug 27, 2021
#
#              Aired On  Number of Episode         Network       Duration  \
# 8    Saturday, Sunday                 20            tvN   1 hr. 20 min.
# 13   Saturday, Sunday                 20  Netflix,  tvN   1 hr. 25 min.
# 14   Sunday, Saturday                 16  Netflix,  tvN   1 hr. 25 min.
# 17   Saturday, Sunday                 24  Netflix,  tvN   1 hr. 20 min.
# 23             Friday                  6        Netflix         50 min.
#
#               Content Rating  \
# 8   15+ - Teens 15 or older
# 13  15+ - Teens 15 or older
# ...

# %%
v=df['Synopsis'].str.contains('U.S')
df[v].head()
# Out:
#             Name  Year of release                   Aired Date  \
# 17  Mr. Sunshine             2018  Jul  7, 2018 - Sep 30, 2018
#
#              Aired On  Number of Episode         Network       Duration  \
# 17   Saturday, Sunday                 24  Netflix,  tvN   1 hr. 20 min.
#
#               Content Rating  \
# 17  15+ - Teens 15 or older
#
#                                              Synopsis  \
# 17  Mr. Sunshine centers on a young boy born into ...
#
#                                                  Cast  \
# 17  Lee Byung Hun, Kim Tae Ri, Kim Min Jung, Yoo Y...
#
#                                            Genre  \
# 17  Military,  Historical,  Romance,  Melodrama
#
#                                                  Tags Rank  Rating  CastNum
# 17  Independent Female Lead, Strong Male Lead, Str...  #18     8.9        6

# %%
d=df['Synopsis'].str.contains('Kim')
df[d].head()
# Out:
#                Name  Year of release                   Aired Date  \
# 5   Prison Playbook             2017  Nov 22, 2017 - Jan 18, 2018
# 6        Reply 1988             2015  Nov  6, 2015 - Jan 16, 2016
# 8         Mr. Queen             2020  Dec 12, 2020 - Feb 14, 2021
# 18           Healer             2014  Dec  8, 2014 - Feb 10, 2015
# 20           Goblin             2016  Dec  2, 2016 - Jan 21, 2017
#
#                 Aired On  Number of Episode         Network       Duration  \
# 5    Wednesday, Thursday                 16  Netflix,  tvN   1 hr. 32 min.
# 6       Friday, Saturday                 20            tvN   1 hr. 40 min.
# 8       Saturday, Sunday                 20            tvN   1 hr. 20 min.
# 18       Monday, Tuesday                 20           KBS2         60 min.
# 20      Friday, Saturday                 16            tvN   1 hr. 22 min.
#
#               Content Rating  \
# 5   15+ - Teens 15 or older
# 6   15+ - Teens 15 or older
# ...

# %%
ddd=pd.concat([df[d],df[v]])

# %%
ddd
# Out:
#                                Name  Year of release  \
# 5                   Prison Playbook             2017
# 6                        Reply 1988             2015
# 8                         Mr. Queen             2020
# 18                           Healer             2014
# 20                           Goblin             2016
# 43                   Dr. Romantic 2             2020
# 50                     Dr. Romantic             2016
# 51                 The Fiery Priest             2019
# 58                           Tunnel             2017
# 68                     Good Manager             2017
# 91                     Yumi's Cells             2021
# 94  What's Wrong with Secretary Kim             2018
# 17                     Mr. Sunshine             2018
#
#                      Aired Date              Aired On  Number of Episode  \
# 5   Nov 22, 2017 - Jan 18, 2018   Wednesday, Thursday                 16
# ...

# %%
data=df.groupby(['Year of release','Network'])['Year of release'].count()
data = data.to_frame(name='count')
data = data.reset_index()

# %%
data
# Out:
#     Year of release          Network  count
# 0              2003             MBC       1
# 1              2012            KBS2       1
# 2              2012             tvN       1
# 3              2013             MBC       1
# 4              2013             SBS       3
# 5              2013            jTBC       1
# 6              2014            KBS2       1
# 7              2014             OCN       1
# 8              2014             SBS       1
# 9              2014             tvN       1
# 10             2015             MBC       1
# 11             2015             SBS       1
# 12             2015             tvN       1
# 13             2016            KBS2       1
# 14             2016             MBC       1
# 15             2016             SBS       2
# 16             2016            jTBC       1
# 17             2016             tvN       3
# 18             2017            KBS2       4
# 19             2017             MBC       1
# ...

# %%
data2=df.groupby(['Year of release','Network'])['Genre'].count()
data2 = data2.to_frame(name='count')
data2 = data2.reset_index()

# %%
data2
# Out:
#     Year of release          Network  count
# 0              2003             MBC       1
# 1              2012            KBS2       1
# 2              2012             tvN       1
# 3              2013             MBC       1
# 4              2013             SBS       3
# 5              2013            jTBC       1
# 6              2014            KBS2       1
# 7              2014             OCN       1
# 8              2014             SBS       1
# 9              2014             tvN       1
# 10             2015             MBC       1
# 11             2015             SBS       1
# 12             2015             tvN       1
# 13             2016            KBS2       1
# 14             2016             MBC       1
# 15             2016             SBS       2
# 16             2016            jTBC       1
# 17             2016             tvN       3
# 18             2017            KBS2       4
# 19             2017             MBC       1
# ...
